# %% [markdown]
# ### Numerical Analysis of Algorithms for a Small Function
# ##$f(x)=0.1X_1^2+2X_2^2$
#
# We will plot the Level sets of this funtions. Then Numerically and Visaully analyse different optimization alorithms for finding the optimal solution.
#
# Later on we will extend this idea to Neural Networks for Image Classification Task.
#
# ##$∇f(x)=[0.2X_1,4X_2]^T$

# %% [markdown]
# ##$v_{t}=\rho  v_{t-1}+ g_t$
#
# ##$w_{new}=w_{old}- \alpha v_{t}$
#
#
# ##$w_{2}=w_{1}-\alpha g_{1}$
#
# ##$w_{3}=w_{2}-\alpha ( \rho g_{1}+g_{2})$
#
# ##$w _{4}=w_{3}-\alpha ( \rho ^{2}g_{1}+ \rho g_{2}+g_{3})$

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize=(13,6))
ax = plt.axes(projection="3d") 
start, stop, n_values = -8, 8, 800
x_vals = np.linspace(start, stop, n_values)
y_vals = np.linspace(start, stop, n_values)
X, Y = np.meshgrid(x_vals, y_vals)
Z = np.sqrt(0.1*X**2 + 2*Y**2)
plt.contourf(X,Y,Z,)
#plt.colorbar(cp)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='winter', edgecolor='none')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(12,7))
#left, bottom, width, height = 100, 0.1, 0.8, 0.8

#ax = plt.axes(projection="2d") 

start, stop, n_values = -8, 8, 800

x_vals = np.linspace(start, stop, n_values)
y_vals = np.linspace(start, stop, n_values)
X, Y = np.meshgrid(x_vals, y_vals)


Z = np.sqrt(0.1*X**2 + 2*Y**2)

plt.contour(X,Y,Z,)
plt.title('Level Sets of the Function',size=20)
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
import numpy as np
def f_2d(x1, x2):
    return 0.1 * x1 ** 2 + 2 * x2 ** 2
f_2d(2,2)
# Out:
# 8.4

# %% [markdown]
# ###RMSprop

# %%
c=1e-6
c
import math

# %%
v1,v2=0,0
gamma=0.9
lr=0.4
x1,x2=-4,-6
l1,l2=[],[]
for i in range(20):
  l1.append(x1)
  l2.append(x2)
  v1=gamma*v1+(1-gamma)*(0.2*x1)**2
  v2=gamma*v2+(1-gamma)*(4*x2)**2
  x1=x1-(lr/math.sqrt(v1+c))*0.2*x1
  x2=x2-(lr/math.sqrt(v2+c))*4*x2
  
  
  print(x1,x2)
# Out:
# -2.7350988179345315 -4.735088946912779
# -1.9954947761425856 -3.9261525301593276
# -1.4767351629164092 -3.3089963490957324
# -1.0913121973533235 -2.805940458284364
# -0.7991924444879607 -2.382261249489984
# -0.577194957247845 -2.0190637704593977
# -0.4096792806906087 -1.7047641988999325
# -0.28495989624396467 -1.4316346246981018
# -0.19375456955204756 -1.1941566502969505
# -0.12847344524356025 -0.9881442159995351
# -0.08287552890808897 -0.81023739591083
# -0.05187951974961861 -0.6575940639579656
# -0.03142935236686611 -0.5276967927014081
# -0.018370910280680865 -0.41823236788835294
# -0.010325356899447045 -0.32702018177867875
# -0.005558794801634129 -0.2519749941751505
# -0.0028538539385544242 -0.1910941221290507
# -0.001390038120550163 -0.1424614349239856
# -0.0006384860403595279 -0.10426183032878389
# -0.0002746033455058856 -0.07480080790233026

# %% [markdown]
# ### ADAGRAD

# %% [markdown]
# ##$G_{t}=G_{t-1}+dw^{2}$
#
# ##$w_{new}=w_{old}-\dfrac {\alpha }{\sqrt {G_{t}+\epsilon}}\odot dw$

# %%
v1,v2=0,0
gamma=0.9
lr=0.4
x1,x2=-4,-6
l1_adagrad,l2_adagrad=[],[]
for i in range(20):
  l1_adagrad.append(x1)
  l2_adagrad.append(x2)
  v1=v1+(0.2*x1)**2
  v2=v2+(4*x2)**2
  x1=x1-(lr/math.sqrt(v1+c))*0.2*x1
  x2=x2-(lr/math.sqrt(v2+c))*4*x2

# %% [markdown]
# ### Gradient Descent

# %%
v1=0
v2=0
gamma=0.9
lr=0.4
x1=-4
x2=-6
l1_gd=[]
l2_gd=[]

for i in range(20):
  l1_gd.append(x1)
  l2_gd.append(x2)
  
  x1=x1-lr*0.2*x1
  x2=x2-lr*4*x2
  3#if x1==0.00 and x2==0.00:
  
  print(x1,x2)
# Out:
# -3.6799999999999997 3.6000000000000014
# -3.3855999999999997 -2.160000000000001
# -3.1147519999999997 1.2960000000000007
# -2.86557184 -0.7776000000000005
# -2.6363260927999996 0.4665600000000003
# -2.4254200053759996 -0.2799360000000002
# -2.2313864049459196 0.16796160000000016
# -2.052875492550246 -0.10077696000000008
# -1.8886454531462264 0.060466176000000066
# -1.7375538168945284 -0.036279705600000045
# -1.598549511542966 0.02176782336000003
# -1.4706655506195287 -0.013060694016000018
# -1.3530123065699664 0.007836416409600012
# -1.244771322044369 -0.004701849845760008
# -1.1451896162808195 0.002821109907456005
# -1.053574446978354 -0.001692665944473603
# -0.9692884912200855 0.0010155995666841621
# -0.8917454119224787 -0.0006093597400104974
# -0.8204057789686804 0.00036561584400629846
# -0.754773316651186 -0.00021936950640377912

# %% [markdown]
# ##$v_{t}=\rho v_{t-1}+\left( 1-\rho \right) \cdot dw^{2}$
#
# ##$w_{new}=w_{old}-\dfrac {\alpha }{\sqrt {v_{t}+\epsilon}}\cdot dw$

# %% [markdown]
# ###Momentum

# %%
v1,v2=0,0
gamma,lr=0.5,0.4
x1,x2=-4,-6
l1_gd_m,l2_gd_m=[],[]
for i in range(20):
  l1_gd_m.append(x1)
  l2_gd_m.append(x2)
  v1=gamma*v1+(0.2*x1)
  v2=gamma*v2+(4*x2)
  x1=x1-lr*v1
  x2=x2-lr*v2

# %% [markdown]
# ##$v_{t}=\rho_1 v_{t-1}+\left( 1-\rho_1 \right) dw$
#
# ##$s_{t}=\rho_2 s_{t-1}+\left( 1-\rho_2 \right) \cdot dw^{2}$
#
# ##$\hat v_t=\dfrac {v_{t}}{1-\rho_1^{t}}$
#
# ##$\hat s_t=\dfrac {s_{t}}{1-\rho_2^{t}}$
#
# ##$w_{new}=w_{old}-\dfrac {\alpha \hat v_t}{\sqrt {\hat s_t}+\epsilon}$
#
# where $\rho_1$ and $\rho_2$ are weighting parameters; $\hat v_t$ and $\hat s_t$ are normalized state variables.

# %%
v1,v2,s1,s2,gamma,beta,lr=0,0,0,0,0.9,0.999,0.4
x1,x2=-6,-6
l1_adam,l2_adam=[],[]
for i in range(20):
  l1_adam.append(x1)
  l2_adam.append(x2)
  v1=gamma*v1+(1-gamma)*(0.2*x1)
  v2=gamma*v2+(1-gamma)*(4*x2)
  s1=beta*s1+(1-beta)*(0.2*x1)**2
  s2=beta*s2+(1-beta)*(4*x2)**2
  m_hat_v1= v1 / (1 - np.power(gamma, i+1))
  m_hat_v2 = v2 / (1 - np.power(gamma, i+1))
  s_hat_s1= s1 / (1 - np.power(beta, i+1))
  s_hat_s2 = s2 / (1 - np.power(beta, i+1))
  x1=x1-(lr)*(m_hat_v1/math.sqrt((s_hat_s1)+c))
  x2=x2-(lr)*(m_hat_v2/math.sqrt((s_hat_s2)+c))
  print(x1,x2)
  if abs(x1)<=0.1 and abs(x2)<0.1:
    break
# Out:
# -5.6000001388888165 -5.600000000347222
# -5.200956533031295 -5.2009562471810975
# -4.803611921095728 -4.8036114790711615
# -4.408796348850341 -4.408795741851055
# -4.0174334532625435 -4.017432672768948
# -3.6305458757729783 -3.6305449138209362
# -3.249259187465591 -3.24925803698751
# -2.874803545861835 -2.874802201098727
# -2.50851214451169 -2.508510601496319
# -2.1518153904923816 -2.1518136475969323
# -1.8062296914808988 -1.8062277500134005
# -1.4733398034108292 -1.4733376682332477
# -1.1547739349006991 -1.1547716150290919
# -0.8521712677466942 -0.8521687768820141
# -0.5671422451009918 -0.5671396020306811
# -0.30122285946257155 -0.30122008827105495
# -0.05582513349309648 -0.05582226352634723

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(figsize=(13,6))
left, bottom, width, height = 100, 0.1, 0.8, 0.8

ax = fig.add_axes([left, bottom, width, height]) 

start, stop, n_values = -8, 8, 100

x_vals = np.linspace(start, stop, n_values)
y_vals = np.linspace(start, stop, n_values)
X, Y = np.meshgrid(x_vals, y_vals)


Z = np.sqrt(0.1*X**2 + 2*Y**2)

plt.contourf(X,Y,Z,)
#plt.colorbar(cp)
plt.plot(l1[:20],l2[:20],color="g",marker="*",markeredgecolor="b",linewidth=3,label="RMSprop Algorithm")
plt.plot(l1_gd[:15],l2_gd[:15],color="red",marker="*",markeredgecolor="black",linewidth=3,label="Gradient Descent")
plt.plot(l1_gd_m[:15],l2_gd_m[:15],color="yellow",marker="*",markeredgecolor="orange",linewidth=3,label="Gradient Descent (Momentum =0.5)")
plt.plot(l1_adagrad[:15],l2_adagrad[:15],color="pink",marker="*",markeredgecolor="black",linewidth=3,label="Adagrad")
plt.plot(l1_adam[:20],l2_adam[:20],color="Brown",marker="*",markeredgecolor="pink",linewidth=3,label="Adam")
plt.figure(figsize=(15,10))
plt.figure(figsize=(15,10))
ax.set_title('Level Sets of the Function',size=20)
ax.set_xlabel('x (cm)')
ax.set_ylabel('y (cm)')
ax.legend()


plt.show()
